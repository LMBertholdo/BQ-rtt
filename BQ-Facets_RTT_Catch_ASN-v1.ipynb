# %% [markdown]
# # Measuring Catchment-RTT by ASN variation by Day in Brazil Node

# %%
#Installing Software
#!pip install --upgrade google-cloud-bigquery[bqstorage,pandas,pandas-gbq,ipython,pyarrow]

# %% [markdown]
# ### Loading Libraries (BQ, Datalab)

# %%
# Checking current project on Google Cloud 
from google.datalab import Context

context = Context.default()
print('The current project is %s' % context.project_id)

# %%
# Use IPython Magics for better performance
# %load_ext google.datalab.kernel
# %load_ext google.cloud.bigquery
# Out:
# The google.datalab.kernel extension is already loaded. To reload it, use:
#   %reload_ext google.datalab.kernel

# %%
#Acess Database on BQ
#from google.cloud import bigquery
# https://cloud.google.com/resource-manager/docs/creating-managing-projects
project_id = 'vp-measurements-testbed'
client = bigquery.Client(project=project_id)

for dataset in client.list_datasets():
  print(dataset.dataset_id)

# %% [markdown]
# ### Testing BQ with a direct result without dataframe

# %%
# %%bq query
# SELECT
#   COUNT (*) as TOTAL
# FROM
#   `vp-measurements-testbed.datasetTestbed.measurements`

# %%
from pandas_gbq import read_gbq

# %%
projectid = 'vp-measurements-testbed'
queryid = """
select 
  count (*) as TOTAL 
from 
  `vp-measurements-testbed.datasetTestbed.measurements`
"""

# %%
read_gbq(query=queryid, project_id=projectid, dialect='standard', verbose=True)

# %%
QUERY = """
SELECT
  timestamp,
  catchment,
  asn,
  src_net,
  origin,
  bgp,
  id,
  rtt
FROM
  `vp-measurements-testbed.datasetTestbed.measurements`
WHERE
  catchment IN ('br-gru-anycast01')
ORDER BY
  timestamp ASC
#LIMIT
# 1000
 """

# %%
# !date
# Out:
# Tue Aug 20 20:43:40 UTC 2019

# %%
read_gbq(query=QUERY, project_id=projectid, dialect='standard', verbose=True)
# Out:
#                                 timestamp         catchment    asn  \
# 0        2019-07-23 01:03:02.102655+00:00  br-gru-anycast01  13335
# 1        2019-07-23 01:03:02.102703+00:00  br-gru-anycast01  56203
# 2        2019-07-23 01:03:02.102719+00:00  br-gru-anycast01  56203
# 3        2019-07-23 01:03:02.102732+00:00  br-gru-anycast01  56203
# 4        2019-07-23 01:03:02.102749+00:00  br-gru-anycast01   2519
# 5        2019-07-23 01:03:02.102783+00:00  br-gru-anycast01  18144
# 6        2019-07-23 01:03:02.102871+00:00  br-gru-anycast01  18144
# 7        2019-07-23 01:03:02.102930+00:00  br-gru-anycast01  18144
# 8        2019-07-23 01:03:02.102980+00:00  br-gru-anycast01  18144
# 9        2019-07-23 01:03:02.103013+00:00  br-gru-anycast01  18144
# 10       2019-07-23 01:03:02.103260+00:00  br-gru-anycast01  18144
# 11       2019-07-23 01:03:02.103395+00:00  br-gru-anycast01  18144
# 12       2019-07-23 01:03:02.103827+00:00  br-gru-anycast01  23969
# 13       2019-07-23 01:03:02.103843+00:00  br-gru-anycast01  23969
# 14       2019-07-23 01:03:02.103876+00:00  br-gru-anycast01  23969
# 15       2019-07-23 01:03:02.103893+00:00  br-gru-anycast01  23969
# 16       2019-07-23 01:03:02.103909+00:00  br-gru-anycast01  23969
# 17       2019-07-23 01:03:02.103927+00:00  br-gru-anycast01  23969
# 18       2019-07-23 01:03:02.103944+00:00  br-gru-anycast01  23969
# 34724579  1564710622118050508  450.654962
# 34724580  1564710622118050508  348.877131
# 34724581  1564710622118050508  442.821662
# 34724582  1564710622118050508  362.575452
# 34724583  1564710622118050508  356.202291
# 34724584  1564710622118050508  351.287288
# 34724585  1564710622118050508  336.628042
# 34724586  1564710622118050508  335.952394
# 34724587  1564710622118050508  336.240521
# 34724588  1564710622118050508  347.585047
# 34724589  1564710622118050508  347.532414
# 34724590  1564710622118050508  337.453471
# 34724591  1564710622118050508  348.078172
# 34724592  1564710622118050508  382.212670
# 34724593  1564710622118050508  344.220829
#
# [34724594 rows x 8 columns]

# %%
# Out:
# Tue Aug 20 21:25:14 UTC 2019

# %%
# Out:
# Tue Aug 20 21:34:20 UTC 2019
# Tue Aug 20 21:34:21 UTC 2019
# Tue Aug 20 21:34:21 UTC 2019
# Tue Aug 20 21:34:22 UTC 2019
# Tue Aug 20 21:34:23 UTC 2019
# Tue Aug 20 21:34:23 UTC 2019
# Tue Aug 20 21:34:24 UTC 2019
# Tue Aug 20 21:34:24 UTC 2019
# 557 ms ± 524 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## Performance text with pandas-gbq

# %%
import pandas

sql = """
  SELECT
    timestamp,
    catchment,
    asn,
    src_net,
    origin,
    bgp,
    id,
    rtt
  FROM
    `vp-measurements-testbed.datasetTestbed.measurements`
  WHERE
    catchment IN ('br-gru-anycast01')
  ORDER BY
    timestamp ASC
  LIMIT
    500000
"""

# %%
# %%timeit
# Run a Standard SQL query using the environment's default project
df = pandas.read_gbq(sql, dialect='standard')
# Out:
# 32.6 s ± 650 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.head()
# Out:
#                          timestamp         catchment    asn   src_net  \
# 0 2019-07-23 01:03:02.102655+00:00  br-gru-anycast01  13335   1.0.0.0
# 1 2019-07-23 01:03:02.102703+00:00  br-gru-anycast01  56203   1.0.4.0
# 2 2019-07-23 01:03:02.102719+00:00  br-gru-anycast01  56203   1.0.5.0
# 3 2019-07-23 01:03:02.102732+00:00  br-gru-anycast01  56203   1.0.6.0
# 4 2019-07-23 01:03:02.102749+00:00  br-gru-anycast01   2519  1.0.16.0
#
#              origin                                bgp                   id  \
# 0  br-gru-anycast01  br-gru-anycast01: 145.90.8.0/24;   1563843782102655803
# 1  br-gru-anycast01  br-gru-anycast01: 145.90.8.0/24;   1563843782102655803
# 2  br-gru-anycast01  br-gru-anycast01: 145.90.8.0/24;   1563843782102655803
# 3  br-gru-anycast01  br-gru-anycast01: 145.90.8.0/24;   1563843782102655803
# 4  br-gru-anycast01  br-gru-anycast01: 145.90.8.0/24;   1563843782102655803
#
#           rtt
# 0    1.853319
# 1  339.661475
# 2  337.275261
# 3  335.605905
# 4  284.860489

# %% [markdown]
# ## Performance text with google-cloud-bigquery

# %%
from google.cloud import bigquery

client = bigquery.Client() 
sql = """
  SELECT
    timestamp,
    catchment,
    asn,
    src_net,
    origin,
    bgp,
    id,
    rtt
  FROM
    `vp-measurements-testbed.datasetTestbed.measurements`
  WHERE
    catchment IN ('br-gru-anycast01')
  ORDER BY
    timestamp ASC
  LIMIT
    500000
"""

# %%
# Run a Standard SQL query using the environment's default project
df = client.query(sql).to_dataframe()

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.head()
# Out:
#                          timestamp         catchment    asn   src_net  \
# 0 2019-07-23 01:03:02.102655+00:00  br-gru-anycast01  13335   1.0.0.0
# 1 2019-07-23 01:03:02.102703+00:00  br-gru-anycast01  56203   1.0.4.0
# 2 2019-07-23 01:03:02.102719+00:00  br-gru-anycast01  56203   1.0.5.0
# 3 2019-07-23 01:03:02.102732+00:00  br-gru-anycast01  56203   1.0.6.0
# 4 2019-07-23 01:03:02.102749+00:00  br-gru-anycast01   2519  1.0.16.0
#
#              origin                                bgp                   id  \
# 0  br-gru-anycast01  br-gru-anycast01: 145.90.8.0/24;   1563843782102655803
# 1  br-gru-anycast01  br-gru-anycast01: 145.90.8.0/24;   1563843782102655803
# 2  br-gru-anycast01  br-gru-anycast01: 145.90.8.0/24;   1563843782102655803
# 3  br-gru-anycast01  br-gru-anycast01: 145.90.8.0/24;   1563843782102655803
# 4  br-gru-anycast01  br-gru-anycast01: 145.90.8.0/24;   1563843782102655803
#
#           rtt
# 0    1.853319
# 1  339.661475
# 2  337.275261
# 3  335.605905
# 4  284.860489

# %% [markdown]
# ### First look at data: (timestamp, catchment=brazil, asn, src_net, origin, bgp, id, rtt)

# %%
# Executes BigQuery QUERY
QUERY = """
SELECT
  timestamp,
  catchment,
  asn,
  src_net,
  origin,
  bgp,
  id,
  rtt
FROM
  `vp-measurements-testbed.datasetTestbed.measurements`
WHERE
  catchment IN ('br-gru-anycast01')
ORDER BY
  timestamp ASC
LIMIT
 100000
 """

# %%
# Load Query --> Dataframe
query_job = client.query(QUERY)
df = query_job.to_dataframe()

# %%
df.head()

# %%
len (df)

# %% [markdown]
# ### Consider just ONE DAY,  same ORIGIN, same CATCHMENT (timestamp="2019-07-24", catchment=Brazil and origin-Brazil)

# %%
QUERY = """
SELECT
  timestamp,
  catchment,
  asn,
  src_net,
  origin,
  bgp,
  id,
  rtt
FROM
  `vp-measurements-testbed.datasetTestbed.measurements`
WHERE
  catchment IN ('br-gru-anycast01') 
  AND ( DATE (timestamp) ='2019-07-24' )

#GROUP BY
# catchment,

ORDER BY
  timestamp ASC

LIMIT
 1000;
"""

# %%
# Load Query --> Dataframe
query_job = client.query(QUERY)
df = query_job.to_dataframe()

# %%
#%load_ext google.colab.data_table

# %%
df

# %% [markdown]
# ### rtt( min, max, avg, mean) in each asn - ASN x RTT

# %%
#%%bigquery --project vp-measurements-testbed df
QUERY = """
SELECT
  timestamp,
  catchment,
  asn,
  src_net,
  origin,
  bgp,
  id,
  rtt
FROM
  `vp-measurements-testbed.datasetTestbed.measurements`
WHERE
  #catchment IN ('br-gru-anycast01') 
  #AND ( DATE (timestamp) ='2019-07-24' )
    ( DATE (timestamp) ='2019-07-24' )
LIMIT 600000
"""

# %%
# Load Query --> Dataframe
query_job = client.query(QUERY)
df = query_job.to_dataframe()

# %%
df.head()

# %%
len(df)

# %% [markdown]
# # Hiden Things

# %%
df

# %% [markdown]
# ### Graphs

# %%
import altair as alt
alt.Chart(df).mark_line().encode(
  x='t0_timestamp',
  y='t0_qt',
  color='catchment'
).interactive(bind_y=True)

# %%
# %%bigquery --project vp-measurements-testbed df
# SELECT
#   timestamp as t0
#   FORMAT_TIMESTAMP('%Y%m%d', timestamp) AS t0_date,
#   FORMAT_TIMESTAMP('%H', timestamp) AS t0_hour,
#   FORMAT_TIMESTAMP('%H', timestamp) AS t0_min,
#   catchment,
#   COUNT(*) AS t0_qt
# FROM
#   `vp-measurements-testbed.datasetTestbed.measurements`
# WHERE
#   catchment IN ('jp-hnd-anycast01')
# GROUP BY
#   t0,
#   t0_date,
#   t0_hour,
#   t0_min,
#   catchment
# ORDER BY
#  t0_date,t0_hour,t0_min ASC
# LIMIT 100
